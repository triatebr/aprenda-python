# %%
#https://medium.com/@kasiarachuta/basic-statistics-in-pandas-dataframe-594208074f85
import pandas as pd
gt= pd.read_csv("GlobalTemperatures.csv")
gt
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0     1750-01-01                   3.034                              3.574
# 1     1750-02-01                   3.083                              3.702
# 2     1750-03-01                   5.626                              3.076
# 3     1750-04-01                   8.490                              2.451
# 4     1750-05-01                  11.573                              2.072
# 5     1750-06-01                  12.937                              1.724
# 6     1750-07-01                  15.868                              1.911
# 7     1750-08-01                  14.750                              2.231
# 8     1750-09-01                  11.413                              2.637
# 9     1750-10-01                   6.367                              2.668
# 10    1750-11-01                     NaN                                NaN
# ...

# %%
gt['LandAverageTemperature'].mean()
# Out:
# 8.374731132075466

# %%
#(axis=0) traz dados de cada coluna do df
gt.mean(axis=0)
# Out:
# LandAverageTemperature                        8.374731
# LandAverageTemperatureUncertainty             0.938468
# LandMaxTemperature                           14.350601
# LandMaxTemperatureUncertainty                 0.479782
# LandMinTemperature                            2.743595
# LandMinTemperatureUncertainty                 0.431849
# LandAndOceanAverageTemperature               15.212566
# LandAndOceanAverageTemperatureUncertainty     0.128532
# dtype: float64

# %%
#(axis=1) traz dados de cada linha da coluna do df
gt.mean(axis=1)
# Out:
# 0       3.304000
# 1       3.392500
# 2       4.351000
# 3       5.470500
# 4       6.822500
# 5       7.330500
# 6       8.889500
# 7       8.490500
# 8       7.025000
# 9       4.517500
# 10           NaN
# 11      2.871000
# 12      2.982000
# 13      2.395000
# 14      4.425500
# 15      5.019000
# 16           NaN
# 17      7.814000
# 18           NaN
# 19      8.350500
# 20      6.664500
# 21           NaN
# 22           NaN
# 23           NaN
# 24      2.068500
# 25           NaN
# 26      4.499000
# 27      5.331500
# 28           NaN
# 29           NaN
#           ...
# 3162    7.877500
# 3163    7.788750
# 3164    7.114500
# 3165    5.899000
# 3166    4.735250
# 3167    3.622750
# 3168    3.226000
# 3169    3.128000
# 3170    4.335500
# 3171    5.654500
# 3172    6.851500
# 3173    7.581125
# 3174    7.821125
# 3175    7.846125
# 3176    7.092000
# 3177    5.935750
# 3178    4.454125
# 3179    3.692750
# 3180    3.304125
# 3181    3.622500
# 3182    4.472750
# ...

# %%
gt['LandAverageTemperature'].describe()
# Out:
# count    3180.000000
# mean        8.374731
# std         4.381310
# min        -2.080000
# 25%         4.312000
# 50%         8.610500
# 75%        12.548250
# max        19.021000
# Name: LandAverageTemperature, dtype: float64

# %%
gt['LandAverageTemperature'].describe(percentiles=[.15,.35,.65,.90])
# Out:
# count    3180.000000
# mean        8.374731
# std         4.381310
# min        -2.080000
# 15%         3.070700
# 35%         5.700950
# 50%         8.610500
# 65%        11.228700
# 90%        14.017000
# max        19.021000
# Name: LandAverageTemperature, dtype: float64

# %%
gt['LandAverageTemperature'].max()
# Out:
# 19.021

# %%
gt['LandAverageTemperature'].min()
# Out:
# -2.08

# %%
gt['LandAverageTemperature'].median()
# Out:
# 8.610499999999998

# %%
gt['LandAverageTemperature'].median(axis=0)
# Out:
# 8.610499999999998
