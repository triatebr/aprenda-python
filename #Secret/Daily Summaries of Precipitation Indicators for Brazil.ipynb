# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/z3dn2qqadclr4ojcem6lrivbec3h63')
df
#https://data.world/hdx/5c9bcc63-1a7b-4c9b-b200-078fab352bda
# Out:
#                       date datatype            station  value  fl_miss  \
# 0      2010-01-01T00:00:00     TPCP  GHCND:BR000352000   3397        0
# 1      2010-01-01T00:00:00     TPCP  GHCND:BR000956000   2979        0
# 2      2010-01-01T00:00:00     TPCP  GHCND:BR002143012   2724        0
# 3      2010-01-01T00:00:00     TPCP  GHCND:BR00E3-0520   5750        0
# 4      2010-01-01T00:00:00     TPCP  GHCND:BR037041370   1670        0
# 5      2010-01-01T00:00:00     TPCP  GHCND:BR038484280    441        0
# 6      2010-01-01T00:00:00     TPCP  GHCND:BR038837530    348        0
# 7      2010-01-01T00:00:00     TPCP  GHCND:BR038983570   1641        0
# 8      2010-01-01T00:00:00     TPCP  GHCND:BRM00082193   1969        0
# 9      2010-01-01T00:00:00     TPCP  GHCND:BRM00082361   4077        0
# 10     2010-01-01T00:00:00     TPCP  GHCND:BRM00083208   5543        0
# 11     2010-01-01T00:00:00     TPCP  GHCND:BRM00083566    632        0
# ...
