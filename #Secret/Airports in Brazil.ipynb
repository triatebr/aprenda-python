# %%
#https://data.world/ourairports/a0a0b44c-834b-459f-9b68-35d90e3a27b6
import pandas as pd
df = pd.read_csv('https://query.data.world/s/trrncj42tt7wc5arvcflrx4cr2zu4e')
df
# Out:
#           id    ident            type  \
# 0       5910     SBGR   large_airport
# 1       5906     SBGL   large_airport
# 2       5974     SBSP   large_airport
# 3       5872     SBBR   large_airport
# 4       5967     SBRJ  medium_airport
# 5       5977     SBSV   large_airport
# 6       5891     SBCT   large_airport
# 7       5951     SBPA  medium_airport
# 8       5905     SBFZ  medium_airport
# 9       5900     SBFI  medium_airport
# 10      5965     SBRF  medium_airport
# 11      5927     SBKP  medium_airport
# 12      5882     SBCF   large_airport
# 13      5901     SBFL   large_airport
# 14      5883     SBCG  medium_airport
# 15      5897     SBEG  medium_airport
# 16      5968     SBRP  medium_airport
# 17      5869     SBBH  medium_airport
# 18      5949     SBNT  medium_airport
# 19      5998     SBVT  medium_airport
# 20       148     SDAM   small_airport
# 21      5931     SBLO  medium_airport
# 22      5870     SBBI  medium_airport
# ...
