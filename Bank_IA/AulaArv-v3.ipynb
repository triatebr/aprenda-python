# %% [markdown]
# ![logos](https://img.freepik.com/free-vector/telemarketing-background-design_1212-238.jpg?size=338&ext=jpg)

# %%
#importando bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime 
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Dados utilizados**
#
# Para o exempçlo de árvore de descisão iremo utilizar um [dataset de Marketing](https://archive.ics.uci.edu/ml/datasets/Bank+Marketing). Ele demonstra valores de campanha de telemarketing de banco portugues. O objetivo e prever de cliente assinará um termo de deposito.

# %%
dados = pd.read_csv('bank-full_.csv', delimiter=';')
dados.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
#verificar as colunas utlizadas
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
# age          45211 non-null int64
# job          45211 non-null object
# marital      45211 non-null object
# education    45211 non-null object
# default      45211 non-null object
# balance      45211 non-null int64
# housing      45211 non-null object
# loan         45211 non-null object
# contact      45211 non-null object
# day          45211 non-null int64
# month        45211 non-null object
# duration     45211 non-null int64
# campaign     45211 non-null int64
# pdays        45211 non-null int64
# previous     45211 non-null int64
# poutcome     45211 non-null object
# y            45211 non-null object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
#Nº de linhas e colunas
dados.shape
# Out:
# (45211, 17)

# %% [markdown]
# ![logos](https://psucd8.files.wordpress.com/2011/10/outlierscatterplot_10001.gif)

# %% [markdown]
# **Processo de detecção de OUTLIERS**

# %% [markdown]
# Em estatística, **outlier** , valor aberrante ou valor atípico, é uma observação que apresenta <p> um grande afastamento das demais da série (que está "fora" dela), ou que é inconsistente. <p>A existência de outliers implica, tipicamente, em prejuízos a interpretação dos resultados dos **testes estatísticos** aplicados às amostras.

# %%
#Lista com as colunas numéricas que não são necessariamente contínus
numerical_columns = [col for col in dados.columns if (dados[col].dtype=='int64' or dados[col].dtype=='float64')]

# %%
numerical_columns
# Out:
# ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %%
dados[numerical_columns].describe().loc[['min', 'max', 'mean', '50%'],:]
# Out:
#            age        balance        day    duration   campaign       pdays  \
# min   18.00000   -8019.000000   1.000000     0.00000   1.000000   -1.000000
# max   95.00000  102127.000000  31.000000  4918.00000  63.000000  871.000000
# mean  40.93621    1362.272058  15.806419   258.16308   2.763841   40.197828
# 50%   39.00000     448.000000  16.000000   180.00000   2.000000   -1.000000
#
#         previous
# min     0.000000
# max   275.000000
# mean    0.580323
# 50%     0.000000

# %% [markdown]
# Repara-se que há no **Balance** um valor de '-8019' ! Estranho neh<p>
#     Esses valor pode atrapalhar todo o processo de **aprendizado de máquina**

# %%
dados[dados['balance'] == dados['balance'].min ()]
# Out:
#        age          job marital  education default  balance housing loan  \
# 12909   26  blue-collar  single  secondary     yes    -8019      no  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome   y
# 12909  cellular    7   jul       299         3     -1         0  unknown  no

# %% [markdown]
# Vamos apagar o registro '12909' do conjunto de dados.

# %%
dados.drop(dados.index[12909], inplace=True)

# %% [markdown]
# ![logos](https://mktes.files.wordpress.com/2014/09/curso-de-web-design-e28093-microcamp-curitiba-centro-aponta-as-vantagens-da-segmentac3a7c3a3o-de-mercado.jpg?)

# %% [markdown]
# Após a importação dos dados (.csv), iremos dividir o arquivo em 2 partes.<p>
#     Pois assim, deixaremos um montante de registros para ser utilizado no modelo de **IA** após o término.<p>
#         Ao todo temos 45211 registros, para o desenvolvimento da IA, usaremos 30000 e deixaremos o restante para a 2ª fase do processo

# %%
#vamos começar embaralhando o conjunto de dados, pois ele pode estar ordenado de alguma forma
dados = dados.sample(frac=1)

# %%
#1ª segmentação 
dados = dados.head(30000)
dados.shape
# Out:
# (30000, 17)

# %%
#2ª segmentação
df = dados.tail(25211)
df.shape
# Out:
# (25211, 17)

# %% [markdown]
# Usaremos para o desenvolvimento do modelo de **IA** o conjunto 'dados'<p>
#     O dataframe 'df' será utilizado em 2º momento

# %% [markdown]
# ![logos](http://emejr.com.br/wp-content/uploads/2018/05/analise-de-falha-640x320.jpg)

# %% [markdown]
# Como podemos perceber os dados estão distribuidos de varias maneiras, temos variaveis categoricas, representadas como objetos e variaveis numericas. Varios dados são desconhecidos, porém estão salvos como 'unknown'.

# %% [markdown]
# **análise exploratoria**
#
# Antes de prevemos os valores vamos fazer uma análise exploratoria, vamos verificar qual idade e qual escolaridade tem maior chance de fechar o deposito.

# %%
idade= sns.FacetGrid(dados, hue="y", aspect=3);
idade.map(sns.kdeplot, "age").add_legend();
idade.set(xlim=(0, 85));

# %%
idade= sns.FacetGrid(dados, hue="y", aspect=3);
idade.map(plt.hist, "age").add_legend();
idade.set(xlim=(0, 85));

# %%
sns.countplot(dados['y'])

# %%
sns.countplot(dados['marital'])

# %%
sns.countplot(dados['education'])

# %% [markdown]
# **Tratamento dos dados**
#
# Porém para podermos utilizar os dados em algum algoritmo de aprendizado  precisamos que todos os valores sejam numericos, assim precisamos converter as colunas que são object.
#
# Existem maneiras de fazermos isto com o sklearn ou com o pandas.
# Vamos mostrar as duas:
#
# - **Pandas:** Com o pandas convertemos a coluna para category, apos isto podemos fazer a função cat.codes.
# - **Sklearn:** Temos que utilizar a classe LabelEnconder, ela funciona como a classe de normalização.

# %%
education = dados['education']

# %%
education.head()
# Out:
# 22805     tertiary
# 17710    secondary
# 44651      unknown
# 3862      tertiary
# 1971       primary
# Name: education, dtype: object

# %%
#Pandas
#Convertendo os dados para categorico
educationConv = education.astype('category')

# pegando o valores de cada categoria
educationConv = educationConv.cat.codes
educationConv[:5]
# Out:
# 22805    2
# 17710    1
# 44651    3
# 3862     2
# 1971     0
# dtype: int8

# %%
education.head()
# Out:
# 22805     tertiary
# 17710    secondary
# 44651      unknown
# 3862      tertiary
# 1971       primary
# Name: education, dtype: object

# %%
#Sklearn
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()
educationConv2 = label.fit_transform(education)
educationConv2[:5]
# Out:
# array([2, 1, 3, 2, 0], dtype=int64)

# %% [markdown]
# Agora vamos usar um loop para podermos fazer a conversão de todos os dados do dataframe

# %%
for coluna in dados:
    if dados[coluna].dtype == object:
        dados[coluna] = dados[coluna].astype('category').cat.codes

# %% [markdown]
# Nota-se como o dataframe ficou após a conversão dos **dados** !

# %%
dados.head()
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 22805   60    4        1          2        1     -311        0     0        0
# 17710   25    7        2          1        0       88        1     0        0
# 44651   48   11        2          3        0     1819        0     0        0
# 3862    29   10        2          2        0        0        1     1        2
# 1971    50    1        0          0        0       31        1     0        2
#
#        day  month  duration  campaign  pdays  previous  poutcome  y
# 22805   25      1       151         6     -1         0         3  0
# 17710   29      5       121        18     -1         0         3  0
# 44651    2     11      1440         1    458         1         0  1
# 3862    16      8       703         4     -1         0         3  0
# 1971     9      8       237         3     -1         0         3  0

# %% [markdown]
# **Separando dados**
#
# Com os dados convertidos vamos separa X e y, e em treino e teste.

# %%
dadosY1 = dados[dados['y']== 1]
dadosY2 = dados[dados['y']== 0]

# %%
dadosY2 = dadosY2.sample(len(dadosY1))

# %%
dados2 = pd.concat([dadosY1,dadosY2])

# %% [markdown]
# Apaga-se a coluna **y** (coluna alvo)

# %%
y = dados.y
x = dados.drop('y',axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
#Optamos por destinar 30% dos dados para treino
np.random.seed(100)
xTreino,xTeste,yTreino,yTeste = train_test_split(x,y, test_size=0.3)

# %% [markdown]
# ### Utilizando árvore de descisão
#
# Agora vamos criar um modelo de descisão como a arvoré de descisão

# %% [markdown]
# ![logos](https://camo.githubusercontent.com/48f1f5cd2785d7bba6324355c0e5e1de2bfa82d5/68747470733a2f2f696d6167652e6962622e636f2f634d6157677a2f53637265656e73686f745f66726f6d5f323031385f31305f30365f30315f31305f35332e706e67)

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# **Entropia** é a medida de impureza de determinada amostra e varia de 0 a 1. Quanto mais próxima de zero, mais pura é a amostra, ou seja, contém elementos de apenas uma determinada classe. Se todos os exemplos fossem perfeitamente divididos entre as classes disponíveis, a entropia teria o seu maio valor possível, que é 1. <p>A fórmula matemática de entropia é a seguinte:
#
# Entropia (S) = ⅀ – pi * log2 pi

# %%
#Criando modelo de classificação
tree = DecisionTreeClassifier(criterion='entropy',max_depth=2)

#Treinando modelo
tree.fit(xTreino,yTreino)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
#Predizendo dados 
preditos = tree.predict(xTeste)

#Verificando modelo
from sklearn.metrics import classification_report
print(classification_report(preditos,yTeste))
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      0.88      0.94      9000
#           1       0.00      0.00      0.00         0
#
# avg / total       1.00      0.88      0.94      9000

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix

confusion_matrix(preditos, yTeste)
# Out:
# array([[7910, 1090],
#        [   0,    0]], dtype=int64)

# %%
preditos = tree.predict_proba(xTeste)
preditos
# Out:
# array([[0.76557482, 0.23442518],
#        [0.9580992 , 0.0419008 ],
#        [0.9580992 , 0.0419008 ],
#        ...,
#        [0.9580992 , 0.0419008 ],
#        [0.9580992 , 0.0419008 ],
#        [0.9580992 , 0.0419008 ]])

# %%
import sklearn.metrics as metrics
# calculate the fpr and tpr for all thresholds of the classification
probs = tree.predict_proba(xTeste)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(yTeste, preds)
roc_auc = metrics.auc(fpr, tpr)

import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
print ("\nAcurácia de classificação = "+str(100*roc_auc)+"%\n")
# Out:
# Acurácia de classificação = 78.8889281944815%

# %% [markdown]
# ![logos](https://cdn4.iconfinder.com/data/icons/robotics-and-artificial-intelligence/512/2-512.png)

# %% [markdown]
# Agora abordaremos a 2ª parte do conjunto de dados separada lá no começo<p>
#     Chamamos de "**df**"<p>
#         Realizaremos todo o tratamento de dados novamente para os mesmos<p>
#             Porém antes realizaremos uma análise dos dados

# %%
df.shape
# Out:
# (25211, 17)

# %%
idade= sns.FacetGrid(df, hue="y", aspect=3);
idade.map(sns.kdeplot, "age").add_legend();
idade.set(xlim=(0, 85));

# %%
idade= sns.FacetGrid(df, hue="y", aspect=3);
idade.map(plt.hist, "age").add_legend();
idade.set(xlim=(0, 85));

# %%
sns.countplot(df['y'])

# %%
sns.countplot(dados['marital'])

# %% [markdown]
# **Tratamento dos Dados**

# %%
df.head()
# Out:
#        age          job   marital  education default  balance housing loan  \
# 7169    37  blue-collar   married  secondary      no    11953     yes  yes
# 37997   34  blue-collar   married  secondary      no      259     yes   no
# 13261   52   technician   married  secondary     yes        0      no   no
# 37465   46     services  divorced  secondary      no     2268     yes   no
# 34580   31   management    single   tertiary      no      130     yes   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome   y
# 7169    unknown   29   may       208         1     -1         0  unknown  no
# 37997  cellular   14   may       291         2     -1         0  unknown  no
# 13261  cellular    8   jul       584         2     -1         0  unknown  no
# 37465  cellular   13   may       281         3     -1         0  unknown  no
# 34580  cellular    5   may       155         1     -1         0  unknown  no

# %%
education = df['education']

# %%
education.head()
# Out:
# 7169     secondary
# 37997    secondary
# 13261    secondary
# 37465    secondary
# 34580     tertiary
# Name: education, dtype: object

# %%
#dessa vez usaremos somente o Sklearn
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()
educationConv2 = label.fit_transform(education)
educationConv2[:5]
# Out:
# array([1, 1, 1, 1, 2], dtype=int64)

# %% [markdown]
# Agora vamos usar um loop para podermos fazer a conversão de todos os dados do dataframe

# %%
for coluna in df:
    if df[coluna].dtype == object:
        df[coluna] = df[coluna].astype('category').cat.codes

# %% [markdown]
# Nota-se como o dataframe ficou após a conversão dos **dados** !

# %%
df.head()
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 7169    37    1        1          1        0    11953        1     1        2
# 37997   34    1        1          1        0      259        1     0        0
# 13261   52    9        1          1        1        0        0     0        0
# 37465   46    7        0          1        0     2268        1     0        0
# 34580   31    4        2          2        0      130        1     0        0
#
#        day  month  duration  campaign  pdays  previous  poutcome  y
# 7169    29      8       208         1     -1         0         3  0
# 37997   14      8       291         2     -1         0         3  0
# 13261    8      5       584         2     -1         0         3  0
# 37465   13      8       281         3     -1         0         3  0
# 34580    5      8       155         1     -1         0         3  0

# %%
xx = df.drop('y',axis=1)

# %%
xx.head()
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 7169    37    1        1          1        0    11953        1     1        2
# 37997   34    1        1          1        0      259        1     0        0
# 13261   52    9        1          1        1        0        0     0        0
# 37465   46    7        0          1        0     2268        1     0        0
# 34580   31    4        2          2        0      130        1     0        0
#
#        day  month  duration  campaign  pdays  previous  poutcome
# 7169    29      8       208         1     -1         0         3
# 37997   14      8       291         2     -1         0         3
# 13261    8      5       584         2     -1         0         3
# 37465   13      8       281         3     -1         0         3
# 34580    5      8       155         1     -1         0         3

# %%
#Predizendo dados 
preditos = tree.predict(xx)
perc_resp = tree.predict_proba(xx)

# %%
preditos
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int8)

# %%
perc_resp[:,0] #todas as linhas da 1ª coluna
# Out:
# array([0.9580992 , 0.9580992 , 0.52071006, ..., 0.9580992 , 0.9580992 ,
#        0.9580992 ])

# %%
perc_resp[:,1] #todas as linhas da 2ª coluna
# Out:
# array([0.0419008 , 0.0419008 , 0.47928994, ..., 0.0419008 , 0.0419008 ,
#        0.0419008 ])

# %%
xx['resp']=preditos

# %%
xx['perc_resp1'] =perc_resp[:,0]

# %%
xx['perc_resp2'] = perc_resp[:,1]

# %%
xx.head(100)
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 7169    37    1        1          1        0    11953        1     1        2
# 37997   34    1        1          1        0      259        1     0        0
# 13261   52    9        1          1        1        0        0     0        0
# 37465   46    7        0          1        0     2268        1     0        0
# 34580   31    4        2          2        0      130        1     0        0
# 41629   49    6        1          2        0     1791        0     0        0
# 615     39    4        1          2        0     2877        1     0        2
# 37314   32    1        1          1        0      -64        1     0        0
# 34230   52   10        1          1        0       94        0     0        0
# 27764   27    9        2          2        0     3064        0     1        0
# 40817   32    4        2          2        0      131        1     0        0
# 12095   28    4        2          1        0      311        1     0        2
# 2968    41    2        1          2        0      221        1     0        2
# 40166   41   10        2          0        0      216        0     0        0
# 304     53    7        1          3        0      257        1     0        2
# 7672    38    9        1          1        0      175        1     0        2
# 16261   60    2        1          0        0        0        0     0        1
# 5227    33    1        2          1        0      372        1     0        2
# 10610   37    4        2          2        0      400        1     0        2
# 25757   34    1        0          1        0     1125        1     1        0
# 2869    45    2        1          0        0     2418        1     0        2
# 6949    38    1        2          3        0      241        1     0        2
# 23240   31    9        2          1        0       46        0     0        0
# 20718   51    1        1          0        0     1694        0     0        0
# 34922   38    9        2          1        0     1255        1     0        0
# 32854   34    4        1          2        0       11        1     0        0
# 44087   60    9        1          1        0      259        0     0        0
# 10976   40    1        1          1        0     1318        1     0        2
# 35955   40    1        1          1        0      498        1     0        0
# 33154   52    7        0          1        0     1430        1     0        1
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 18502   42    0        2          1        0     4343        0     0        0
# 2334    31    0        2          1        0      296        1     0        2
# 8799    33    1        1          1        0      355        1     0        2
# 2877    30    1        1          1        0      938        1     0        2
# 29002   43    9        1          1        0      576        0     0        0
# 38533   34    4        2          2        0     2360        1     0        0
# 3633    27    9        1          1        0        7        1     0        2
# 2667    43    2        1          1        0       59        0     0        2
# 28909   46    4        1          2        0      699        0     0        0
# 11827   50    3        1          0        0     1098        0     0        2
# 14330   35    1        2          0        0     -230        1     0        0
# 17724   47    0        2          1        0     1305        0     0        0
# 16712   32    4        2          2        0      597        0     1        0
# 31275   30    8        2          2        0     2539        0     0        1
# 43646   34    1        1          1        0     1221        1     0        0
# 13760   29    7        1          1        0       13        0     0        0
# 41645   36    0        1          2        0     1145        1     0        0
# 41533   32    4        2          2        0     1954        1     1        0
# 44381   38    9        2          2        0     1727        0     0        1
# 40844   57    4        1          1        0     2155        0     1        0
# 22914   40    2        1          1        0       50        0     0        0
# 11062   45   11        1          3        0     1979        0     0        2
# 33210   32    1        1          1        0     1281        1     0        0
# 41691   34    2        2          1        0      318        1     0        0
# 26263   33    1        1          0        0        0        1     0        0
# 4731    30    7        2          1        0      432        1     0        2
# 31923   36    2        1          2        0        0        1     0        0
# 39829   55    1        1          1        0    16873        0     0        0
# 20330   33    9        1          2        0     2586        0     0        0
# 34465   32    4        2          2        0      112        1     0        0
#
#        day  month  duration  campaign  pdays  previous  poutcome  resp  \
# 7169    29      8       208         1     -1         0         3     0
# 37997   14      8       291         2     -1         0         3     0
# 13261    8      5       584         2     -1         0         3     0
# 37465   13      8       281         3     -1         0         3     0
# 34580    5      8       155         1     -1         0         3     0
# 41629   25     11       139         1     -1         0         3     0
# 615      6      8       278         1     -1         0         3     0
# 37314   13      8       641         1     -1         0         3     0
# 34230    4      8       223         9      4         1         2     0
# 27764   28      4       389         1     -1         0         3     0
# 40817   11      1       112         1     81         1         1     0
# 12095   20      6        23        13     -1         0         3     0
# 2968    14      8        57         2     -1         0         3     0
# 40166    5      6       577         3     -1         0         3     0
# 304      5      8       209         2     -1         0         3     0
# 7672    30      8       264         1     -1         0         3     0
# 16261   23      5        40         1     -1         0         3     0
# 5227    23      8        92         1     -1         0         3     0
# 10610   16      6       244         1     -1         0         3     0
# 25757   19      9       141         2     -1         0         3     0
# 2869    14      8       120         1     -1         0         3     0
# 6949    28      8       172         2     -1         0         3     0
# 23240   27      1       313         6     -1         0         3     0
# 20718   13      1       186         2     -1         0         3     0
# 34922    6      8       120         1    170         4         0     0
# 32854   17      0        22         1    150         2         0     0
# 44087    6      5       396         1    386         2         2     0
# 10976   17      6       681         2     -1         0         3     0
# 35955    8      8        55         2    298         4         0     0
# 33154   20      0       121         4     -1         0         3     0
# ...    ...    ...       ...       ...    ...       ...       ...   ...
# 18502   31      5       245         4     -1         0         3     0
# 2334    13      8       161         1     -1         0         3     0
# 8799     4      6        87         3     -1         0         3     0
# 2877    14      8       159         1     -1         0         3     0
# 29002    2      3       229         1     -1         0         3     0
# 38533   15      8       137         2    176         1         0     0
# 3633    15      8        98         2     -1         0         3     0
# 2667    13      8       437         2     -1         0         3     0
# 28909    2      3       241         1     -1         0         3     0
# 11827   20      6       174         3     -1         0         3     0
# 14330   14      5       183         3     -1         0         3     0
# 17724   29      5       172         2     -1         0         3     0
# 16712   24      5       869         1     -1         0         3     0
# 31275    5      7       199         5     -1         0         3     0
# 43646    6      8       182         1     90         8         0     0
# 13760   10      5        90         1     -1         0         3     0
# 41645   29     11        75         1    239         2         0     0
# 41533   10     11       107         1     -1         0         3     0
# 44381    2      1       141         2    185         6         1     0
# 40844   11      1        82         2     -1         0         3     0
# 22914   26      1        63         6     -1         0         3     0
# 11062   17      6        76         3     -1         0         3     0
# 33210   20      0       222         1     -1         0         3     0
# 41691    6     10        88         1    169         3         0     0
# 26263   20      9       173         1     -1         0         3     0
# 4731    20      8       340         3     -1         0         3     0
# 31923    9      0       339         1     -1         0         3     0
# 39829    1      6        78         2     -1         0         3     0
# 20330   11      1       117         3     -1         0         3     0
# 34465    5      8       118         1     -1         0         3     0
#
#        perc_resp1  perc_resp2
# 7169     0.958099    0.041901
# 37997    0.958099    0.041901
# 13261    0.520710    0.479290
# 37465    0.958099    0.041901
# 34580    0.958099    0.041901
# 41629    0.958099    0.041901
# 615      0.958099    0.041901
# 37314    0.520710    0.479290
# 34230    0.958099    0.041901
# 27764    0.958099    0.041901
# 40817    0.818555    0.181445
# 12095    0.958099    0.041901
# 2968     0.958099    0.041901
# 40166    0.520710    0.479290
# 304      0.958099    0.041901
# 7672     0.958099    0.041901
# 16261    0.958099    0.041901
# 5227     0.958099    0.041901
# 10610    0.958099    0.041901
# 25757    0.958099    0.041901
# 2869     0.958099    0.041901
# 6949     0.958099    0.041901
# 23240    0.958099    0.041901
# 20718    0.958099    0.041901
# 34922    0.818555    0.181445
# 32854    0.818555    0.181445
# 44087    0.818555    0.181445
# 10976    0.520710    0.479290
# 35955    0.818555    0.181445
# 33154    0.958099    0.041901
# ...           ...         ...
# 18502    0.958099    0.041901
# 2334     0.958099    0.041901
# 8799     0.958099    0.041901
# 2877     0.958099    0.041901
# 29002    0.958099    0.041901
# 38533    0.818555    0.181445
# 3633     0.958099    0.041901
# 2667     0.765575    0.234425
# 28909    0.958099    0.041901
# 11827    0.958099    0.041901
# 14330    0.958099    0.041901
# 17724    0.958099    0.041901
# 16712    0.520710    0.479290
# 31275    0.958099    0.041901
# 43646    0.818555    0.181445
# 13760    0.958099    0.041901
# 41645    0.818555    0.181445
# 41533    0.958099    0.041901
# 44381    0.818555    0.181445
# 40844    0.958099    0.041901
# 22914    0.958099    0.041901
# 11062    0.958099    0.041901
# 33210    0.958099    0.041901
# 41691    0.818555    0.181445
# 26263    0.958099    0.041901
# 4731     0.958099    0.041901
# 31923    0.958099    0.041901
# 39829    0.958099    0.041901
# 20330    0.958099    0.041901
# 34465    0.958099    0.041901
#
# [100 rows x 19 columns]
