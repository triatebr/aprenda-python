# %% [markdown]
# ![logos](http://cdn.wittysparks.com/wp-content/uploads/2017/08/09210754/Machine-Learning.jpg)

# %% [markdown]
# Nesse tutorial teremos o 1º contato com a library de Aprendizado de máquina: <b> Scikit-learn </b>.<p>
# Vamos aprender e interagir com algo supreendente chamado <b> IA - Inteligência Artificial </b>, para o melhor aproveitamento faz-se necessário conhecer <b> PANDAS </b> (ou biblioteca incrível) e sobre visualização de dados (pois criaremos gráficos incríveis).<p>
#     Não tenha receio de começar com <b> PYTHON </b>, inicie-se e aventure-se! O conjunto de dados escolhido está no site da <b> IBM </b>, com infos da campanha de vendas de um fornecedor atacadista de peças automotivas.

# %%
#acessando a URL com os dados
#https://www.dataquest.io/blog/sci-kit-learn-tutorial/
import pandas as pd
url = "https://community.watsonanalytics.com/wp-content/uploads/2015/04/WA_Fn-UseC_-Sales-Win-Loss.csv"

# %%
#converter o csv em um dataframe
sales_data = pd.read_csv(url)

# %%
#com tudo devidamente importado vamos verificar algumas coisas do dataframe
#5 primeiras linhas ... caso queira algo difeente tente por ex: 'sales_data.head(50)'
#advinha o que acontecerá?!?!? Por default o '.head()' mostra as 5 primeira linhas
sales_data.head()
# Out:
#    Opportunity Number     Supplies Subgroup          Supplies Group  \
# 0             1641984  Exterior Accessories         Car Accessories
# 1             1658010  Exterior Accessories         Car Accessories
# 2             1674737      Motorcycle Parts  Performance & Non-auto
# 3             1675224         Shelters & RV  Performance & Non-auto
# 4             1689785  Exterior Accessories         Car Accessories
#
#       Region Route To Market  Elapsed Days In Sales Stage Opportunity Result  \
# 0  Northwest    Fields Sales                           76                Won
# 1    Pacific        Reseller                           63               Loss
# 2    Pacific        Reseller                           24                Won
# 3    Midwest        Reseller                           16               Loss
# 4    Pacific        Reseller                           69               Loss
#
#    Sales Stage Change Count  Total Days Identified Through Closing  \
# ...

# %% [markdown]
# Exploração de Dados<p> <b> </b>
#     A exploração de dados é um passo muito importante em qualquer projeto de <b> Ciência de Dados </b>ou <b>Aprendizado de Máquina</b>. Mesmo uma exploração rápida do conjunto de dados pode nos dar informações importantes que, de outra forma, poderíamos perder, e essas informações podem sugerir questões importantes que podemos tentar responder por meio de nosso projeto.

# %% [markdown]
# Agora que visualizamos os registros iniciais de nosso <b>dataframe</b>, vamos tentar visualizar os últimos registros no conjunto de dados. Isso pode ser feito usando o tail()método, que tem sintaxe semelhante ao head().

# %%
#os último 5 registros são da linha 78020 até 78024
sales_data.tail()
# Out:
#        Opportunity Number        Supplies Subgroup          Supplies Group  \
# 78020            10089932  Batteries & Accessories         Car Accessories
# 78021            10089961            Shelters & RV  Performance & Non-auto
# 78022            10090145     Exterior Accessories         Car Accessories
# 78023            10090430     Exterior Accessories         Car Accessories
# 78024            10094255     Interior Accessories         Car Accessories
#
#              Region Route To Market  Elapsed Days In Sales Stage  \
# 78020     Southeast        Reseller                            0
# 78021     Northeast        Reseller                            0
# 78022     Southeast        Reseller                            0
# 78023     Southeast    Fields Sales                            0
# 78024  Mid-Atlantic        Reseller                            0
#
#       Opportunity Result  Sales Stage Change Count  \
# 78020               Loss                         2
# ...

# %% [markdown]
# Agora, seria bom se pudéssemos ver os <b>diferentes tipos de dados disponíveis</b> neste conjunto de dados.
# Esta informação pode ser útil no caso de precisarmos fazer alguma conversão mais tarde. Podemos fazer isso com o dtypes():

# %%
sales_data.dtypes
# Out:
# Opportunity Number                           int64
# Supplies Subgroup                           object
# Supplies Group                              object
# Region                                      object
# Route To Market                             object
# Elapsed Days In Sales Stage                  int64
# Opportunity Result                          object
# Sales Stage Change Count                     int64
# Total Days Identified Through Closing        int64
# Total Days Identified Through Qualified      int64
# Opportunity Amount USD                       int64
# Client Size By Revenue                       int64
# Client Size By Employee Count                int64
# Revenue From Client Past Two Years           int64
# Competitor Type                             object
# Ratio Days Identified To Total Days        float64
# Ratio Days Validated To Total Days         float64
# Ratio Days Qualified To Total Days         float64
# ...

# %% [markdown]
# <b> </b> <b> Visualização de dados</b> <p>
# Agora que fizemos algumas explorações básicas de dados, vamos tentar criar alguns gráficos interessantes para representar visualmente os dados e descobrir mais histórias ocultas no conjunto de dados. Vamos investigar e entender.

# %%
#usaremos uma biblioteca incrível chamada 'Seaborn', para visualização de dados
#antes de tudo precisamos ver se a mesma encontra-se instalada
#Dados da coluna 'Opportunity Result'

import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid", color_codes=True)
sns.set(rc={'figure.figsize':(11.7,8.27)})

sns.countplot('Route To Market',data=sales_data,hue = 'Opportunity Result')
sns.despine(offset=10, trim=True)
plt.show()

# %% [markdown]
# Curioso e querendo saber + sobre o [Seaborn](https://seaborn.pydata.org/generated/seaborn.countplot.html) !?!?!<p>
#     Agora veremos outra popular forma de visualização de dados chamada <b>'ViolinPlots'</b> (logo mais você entenderá a razão do nome).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(16.7,13.27)})

# %%
sns.violinplot(x="Opportunity Result",y="Client Size By Revenue", hue="Opportunity Result", data=sales_data);
plt.show()
# Out:
# C:\Users\Lucas Barros\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Prestando muito bem atenção, você perceberá que nosso gráfico representa (ou se parece risos) com um violino.<p>
#     Usamos muito esse tipode gráfico pois eles no traz como os dados estão realmente distríbuidos e quais recursos possuem maior concetração de dados. Para esse exemplo usamos a coluna <b>'Client Size By Revenue'</b>.

# %% [markdown]
# <b> Dados de pré-processamento </b> <p>
#     Agora que temos uma boa compreensão de como são nossos dados, podemos nos preparar para <b> criar modelos de previsão</b> usando o scikit-learn.
#
# Vimos em nossa exploração inicial que a maioria das colunas em nosso conjunto de dados são strings, mas os algoritmos no scikit-learn entendem <b>apenas dados numéricos</b>. Felizmente, a biblioteca scikit-learn nos fornece muitos métodos para converter dados de string em dados numéricos.

# %%
#import the necessary module
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

encoded_value = le.fit_transform(["paris", "paris", "tokyo", "amsterdam"])
print(encoded_value)
# Out:
# [1 1 2 0]

# %% [markdown]
# Acima usamos o 'fit_transform()', método pertencente ao LabelEncoder() para codificar a coluna 'Route To Market'<p>
#     4 valores foram utilizados para o nosso exemplo: "paris", "paris", "tokyo", "amsterdam"

# %% [markdown]
# Se estou conseguindo deixar você mais curioso, estou indo bem então! risos<p>
#     Para saber mais sobre o [scikit-learn](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html) !?!?!<p>

# %%
# aprendemos um pouco sobre o 'LabelEncoder()' e como converter dados categóricos em dados numéricos
# vamos visualizar como estão as colunas que são formadas por String
# lá atrás usamos a sintaze 'sales_data.dtypes' lembra? 
print("Supplies Subgroup' : ",sales_data['Supplies Subgroup'].unique())
print("Region : ",sales_data['Region'].unique())
print("Route To Market : ",sales_data['Route To Market'].unique())
print("Opportunity Result : ",sales_data['Opportunity Result'].unique())
print("Competitor Type : ",sales_data['Competitor Type'].unique())
print("'Supplies Group : ",sales_data['Supplies Group'].unique())
# Out:
# Supplies Subgroup' :  ['Exterior Accessories' 'Motorcycle Parts' 'Shelters & RV'
#  'Garage & Car Care' 'Batteries & Accessories' 'Performance Parts'
#  'Towing & Hitches' 'Replacement Parts' 'Tires & Wheels'
#  'Interior Accessories' 'Car Electronics']
# Region :  ['Northwest' 'Pacific' 'Midwest' 'Southwest' 'Mid-Atlantic' 'Northeast'
#  'Southeast']
# Route To Market :  ['Fields Sales' 'Reseller' 'Other' 'Telesales' 'Telecoverage']
# Opportunity Result :  ['Won' 'Loss']
# Competitor Type :  ['Unknown' 'Known' 'None']
# 'Supplies Group :  ['Car Accessories' 'Performance & Non-auto' 'Tires & Wheels'
#  'Car Electronics']

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

#conversão das colunas categóricas em numéricas
sales_data['Supplies Subgroup'] = le.fit_transform(sales_data['Supplies Subgroup'])
sales_data['Region'] = le.fit_transform(sales_data['Region'])
sales_data['Route To Market'] = le.fit_transform(sales_data['Route To Market'])
sales_data['Opportunity Result'] = le.fit_transform(sales_data['Opportunity Result'])
sales_data['Competitor Type'] = le.fit_transform(sales_data['Competitor Type'])
sales_data['Supplies Group'] = le.fit_transform(sales_data['Supplies Group'])

sales_data.head()
# Out:
#    Opportunity Number  Supplies Subgroup  Supplies Group  Region  \
# 0             1641984                  2               0       3
# 1             1658010                  2               0       4
# 2             1674737                  5               2       4
# 3             1675224                  8               2       1
# 4             1689785                  2               0       4
#
#    Route To Market  Elapsed Days In Sales Stage  Opportunity Result  \
# 0                0                           76                   1
# 1                2                           63                   0
# 2                2                           24                   1
# 3                2                           16                   0
# 4                2                           69                   0
#
#    Sales Stage Change Count  Total Days Identified Through Closing  \
# 0                        13                                    104
# ...

# %% [markdown]
# Agora <b> SIM </b>, avançamos bem! Com todos os dados já convertidos podemos em breve a construção do <b> Modelo Preditivo </b>

# %% [markdown]
# <b> Conjunto de Treinamento e Conjunto de Testes </b><p>
# Um algoritmo de aprendizado de máquina precisa ser treinado em um conjunto de dados para aprender as relações entre diferentes recursos e como esses recursos afetam a variável de destino. Para isso, precisamos dividir todo o <b>conjunto de dados em dois conjuntos</b>. Um é o conjunto de <b>treinamento</b> no qual vamos treinar nosso algoritmo para construir um modelo.<p> O outro é o conjunto de <b>testes</b> no qual testaremos nosso modelo para ver quão precisas são suas previsões.

# %%
#selecionando as colunas 'Opportunity Number' e 'Opportunity Result'
#não precisaremos das colunas citadas, pois a 1ª refere-se a um identificador excluisivo para cada registros e 
#e a outra é o nosso alvo! O que buscamos logo, não faz sentido possuir as mesmas
cols = [col for col in sales_data.columns if col not in ['Opportunity Number','Opportunity Result']]

data = sales_data[cols]
target = sales_data['Opportunity Result']
data.head(n=2)
# Out:
#    Supplies Subgroup  Supplies Group  Region  Route To Market  \
# 0                  2               0       3                0
# 1                  2               0       4                2
#
#    Elapsed Days In Sales Stage  Sales Stage Change Count  \
# 0                           76                        13
# 1                           63                         2
#
#    Total Days Identified Through Closing  \
# 0                                    104
# 1                                    163
#
#    Total Days Identified Through Qualified  Opportunity Amount USD  \
# 0                                      101                       0
# 1                                      163                       0
#
#    Client Size By Revenue  Client Size By Employee Count  \
# 0                       5                              5
# 1                       3                              5
#
#    Revenue From Client Past Two Years  Competitor Type  \
# ...

# %% [markdown]
# Estamos todos prontos para definir nossos recursos e segmentar em dois quadros de dados separados. Em seguida, vamos dividir as dataframes 'data' e target' em conjuntos de formação e conjuntos de testes. Ao dividir o conjunto de dados, manteremos <b>30% dos dados como dados de teste</b> e os <b> 70% restantes como dados de treinamento</b>. Porém, fique a vontade para usar o modelo mais a sua escolha, usa-se muito o príncipio <b> '80/20'</b>, no qual são mantidos '80%' com dados de treinamento e os outros 20%' como dados de teste.

# %%
#criação do 'data_train' e do 'data_test'
from sklearn.model_selection import train_test_split

data_train, data_test, target_train, target_test = train_test_split(data,target, test_size = 0.30, random_state = 10)

# %% [markdown]
# Para a escolha do melhor algoritmo use o <b> MAP </b> como referência<p>
# Machine Learn [MAP](https://scikit-learn.org/stable/tutorial/machine_learning_map/) !?!?!<p>

# %% [markdown]
# ![MAP](https://scikit-learn.org/stable/_static/ml_map.png)

# %% [markdown]
# O algoritmo que vamos usar para os nossos dados de vendas será o <b> [Gaussian Naive Bayes](http://scikit-learn.org/stable/modules/naive_bayes.html)</b> !?!?!<p>

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

gnb = GaussianNB()

pred = gnb.fit(data_train, target_train).predict(data_test)

print("Naive-Bayes accuracy Teste: ",accuracy_score(target_test, pred, normalize = True))
# Out:
# Naive-Bayes accuracy Teste:  0.7590567327409433

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

gnb = GaussianNB()

pred = gnb.fit(data_train, target_train).predict(data_train)

print("Naive-Bayes accuracy Treinamento: ",accuracy_score(target_train, pred, normalize = True))
# Out:
# Naive-Bayes accuracy Treinamento:  0.7579508211728949
