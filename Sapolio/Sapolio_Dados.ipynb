# %% [markdown]
# ![logos](https://uaulimpeza.com.br/blog/wp-content/uploads/sites/2/2016/03/Produtos_de_limpeza_saiba_como_escolher_os_ideiais_para_a_sua_casa_2.jpg-825x542.jpeg)

# %% [markdown]
# Hoje veremos a relevãncia na **Limpeza dos Dados**, e como fazer na **prática** mesmo ...<p>
#     Conteúdos teóricos são importantes apra o aprendizados, porém colocando a **mão na massa** que aprendemos!<p>
#         Prepare-se a **JORNADA** será rica de conhecimento e muito interessante

# %%
# Como sempre começamos importantes as bibliotecas que usaremos
import pandas as pd
import numpy as np
from functools import reduce

# %% [markdown]
# ![logos](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSPmW7qCXS8DGymF-oKmjDcf_nCJjUeJ_8hJ9o6yj68U1aLT3yM)

# %%
# 1º dataframe: atribuição realizada e na sequenacia já listamos as 5 primeiras linhas
# essa visualização de Dados é essencial, pois a nossa 1ª análise será feita a partir de agora
df = pd.read_csv('BL-Flickr-Images-Book.csv')
df.head()
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %% [markdown]
# ![logos](https://canalcienciascriminais.com.br/wp-content/uploads/2018/01/investiga%C3%A7%C3%A3o-preliminar.jpg)

# %% [markdown]
# Ao visualizar essas poucas linhas, já vemos algumas coisas que 'nos saltam aos olhos'!<p>
#     Como: colunas com campos 'Nulos' (**NaN**), campo de Data sem formatação entre outros <p>
#         Vamos lá ... aprender, criar , codar e fazer !

# %% [markdown]
# ## Descartando colunas desnecessárias
# REsolvemos que muitas colunas não trazem informações alguma, o que fazemos?<p>
#     Atuar com poucos dados geram uma eficiência maior! Vamos descarta-las, como? Veja aí ...

# %%
# criamos uma variável com todas as colunas, pois o 'delete' será feito de uma vez...
to_drop = ['Edition Statement',
           'Corporate Author',
           'Corporate Contributors',
           'Former owner',
           'Engraver',
           'Contributors',
           'Issuance type',
           'Shelfmarks']
# sintaxe simples para drop das colunas
df.drop(to_drop, inplace = True, axis = 1)
df.head()
# Out:
#    Identifier      Place of Publication Date of Publication  \
# 0         206                    London         1879 [1878]
# 1         216  London; Virtue & Yorston                1868
# 2         218                    London                1869
# 3         472                    London                1851
# 4         480                    London                1857
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of “All for Gr...
# 3          James Darling  Welsh Sketches, chiefly ecclesiastical, to the...
# 4   Wertheim & Macintosh  [The World in which I live, and my place in it...
#
#       Author                                         Flickr URL
# 0      A. A.  http://www.flickr.com/photos/britishlibrary/ta...
# ...

# %%
# comando simples para listar a qtde de registros, campo a campo
df.count()
# Out:
# Place of Publication    8287
# Date of Publication     7320
# Publisher               4092
# Title                   8287
# Author                  6509
# Flickr URL              8287
# dtype: int64

# %% [markdown]
# ## Indíce para o conjunto de Dados
# Para melhorar a nossa performance vamos criar um indíce...

# %%
df.set_index('Identifier', inplace = True)
df.head()
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London         1879 [1878]
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472         Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# ...

# %%
# Vamos começar o trabalho de limpeza | higienização dos Dados pelo campo de Date of Publication
# Veja bem que não há padrão algum nas info's ....
df['Date of Publication'].head(25)
# Out:
# Identifier
# 206            1879 [1878]
# 216                   1868
# 218                   1869
# 472                   1851
# 480                   1857
# 481                   1875
# 519                   1872
# 667                    NaN
# 874                   1676
# 1143                  1679
# 1280                  1802
# 1808                  1859
# 1905                  1888
# 1929           1839, 38-54
# 2836                  1897
# 2854                  1865
# 2956               1860-63
# 2957                  1873
# 3017                  1866
# 3131                  1899
# 4598                  1814
# 4884                  1820
# 4976                  1800
# 5382    1847, 48 [1846-48]
# 5385               [1897?]
# Name: Date of Publication, dtype: object

# %% [markdown]
# ## Limpeza da coluna usando a função `.apply`
# Vamos desconsiderar muitos caracteres ...

# %%
unwanted_characters = ['[', ',', '-']

def clean_dates(item):
    dop= str(item.loc['Date of Publication'])
    
    if dop == 'nan' or dop[0] == '[':
        return np.NaN
    
    for character in unwanted_characters:
        if character in dop:
            character_index = dop.find(character)
            dop = dop[:character_index]
    
    return dop

df['Date of Publication'] = df.apply(clean_dates, axis = 1)

# %%
df.head()
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London               1879
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472         Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# ...

# %%
# Alternativa para limpar os dados de 'Date of Publication'
unwanted_characters = ['[', ',', '-']

def clean_dates(dop):
    dop = str(dop)
    if dop.startswith('[') or dop == 'nan':
        return 'NaN'
    for character in unwanted_characters:
        if character in dop:
            character_index = dop.find(character)
            dop = dop[:character_index]
    return dop

df['Date of Publication'] = df['Date of Publication'].apply(clean_dates)
df.head()
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London               1879
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472         Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# ...

# %%
# Agora vamos o 2º campo ... a LIMPAR!
# Disparidades e coisas esdruxúlas  ... HORROROSAS! risos
df['Author'].head(25)
# Out:
# Identifier
# 206                                                 A. A.
# 216                                             A., A. A.
# 218                                             A., A. A.
# 472                                             A., E. S.
# 480                                             A., E. S.
# 481                                             A., E. S.
# 519                                             A., F. E.
# 667                                         A., J.|A., J.
# 874                                                Remaʿ.
# 1143                                               A., T.
# 1280                                                  NaN
# 1808                                         AALL, Jacob.
# 1905    AAR, Ermanno - pseud. [i.e. Luigi Giuseppe Oro...
# 1929                                                  NaN
# 2836                            ABATE, Giovanni Agostino.
# 2854                                    ABATI, Francesco.
# ...

# %%
def clean_author_names(author):
    
    author = str(author)
    
    if author == 'nan':
        return 'NaN'
    
    author = author.split(',')

    if len(author) == 1:
        name = filter(lambda x: x.isalpha(), author[0])
        return reduce(lambda x, y: x + y, name)
    
    last_name, first_name = author[0], author[1]

    first_name = first_name[:first_name.find('-')] if '-' in first_name else first_name
    
    if first_name.endswith(('.', '.|')):
        parts = first_name.split('.')
        
        if len(parts) > 1:
            first_occurence = first_name.find('.')
            final_occurence = first_name.find('.', first_occurence + 1)
            first_name = first_name[:final_occurence]
        else:
            first_name = first_name[:first_name.find('.')]
    
    last_name = last_name.capitalize()
    
    return f'{first_name} {last_name}'


df['Author'] = df['Author'].apply(clean_author_names)

# %%
df.head()
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London               1879
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
#
#                                                         Title    Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A        AA
# 216         All for Greed. [A novel. The dedication signed...   A. A A.
# 218         Love the Avenger. By the author of “All for Gr...   A. A A.
# 472         Welsh Sketches, chiefly ecclesiastical, to the...   E. S A.
# ...

# %%
# O desafio continua ! Sejamos fortes bravos 
df['Title'].head(25)
# Out:
# Identifier
# 206                     Walter Forbes. [A novel.] By A. A
# 216     All for Greed. [A novel. The dedication signed...
# 218     Love the Avenger. By the author of “All for Gr...
# 472     Welsh Sketches, chiefly ecclesiastical, to the...
# 480     [The World in which I live, and my place in it...
# 481     [The World in which I live, and my place in it...
# 519     Lagonells. By the author of Darmayne (F. E. A....
# 667     The Coming of Spring, and other poems. By J. A...
# 874     A Warning to the inhabitants of England, and L...
# 1143    A Satyr against Vertue. (A poem: supposed to b...
# 1280    An Account of the many and great Loans, Benefa...
# 1808    Erindringer som Bidrag til Norges Historie fra...
# 1905    Gli Studi storici in terra d'Otranto ... Framm...
# 1929    De Aardbol. Magazijn van hedendaagsche land- e...
# 2836    Cronache Savonesi dal 1500 al 1570 ... Accresc...
# 2854    See-Saw; a novel ... Edited [or rather, writte...
# ...

# %%
def clean_title(title):
    
    if title == 'nan':
        return 'NaN'
    
    if title[0] == '[':
        title = title[1: title.find(']')]
        
    if 'by' in title:
        title = title[:title.find('by')]
    elif 'By' in title:
        title = title[:title.find('By')]
        
    if '[' in title:
        title = title[:title.find('[')]

    title = title[:-2]
        
    title = list(map(str.capitalize, title.split()))
    return ' '.join(title)
    
df['Title'] = df['Title'].apply(clean_title)
df.head()
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London               1879
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
#
#                                                         Title    Author  \
# Identifier
# 206                                             Walter Forbes        AA
# 216                                             All For Greed   A. A A.
# 218                                          Love The Avenger   A. A A.
# 472         Welsh Sketches, Chiefly Ecclesiastical, To The...   E. S A.
# ...

# %% [markdown]
# ## Usando `.str` para limpeza de Colunas

# %%
#4157862 and 4159587
df.loc[4159587]
# Out:
# Place of Publication                                  Newcastle upon Tyne
# Date of Publication                                                  1834
# Publisher                                                Mackenzie & Dent
# Title                   An Historical, Topographical And Descriptive V...
# Author                                               E. (Eneas) Mackenzie
# Flickr URL              http://www.flickr.com/photos/britishlibrary/ta...
# Name: 4159587, dtype: object

# %%
pub = df['Place of Publication']
df['Place of Publication'] = np.where(pub.str.contains('London'), 'London',
    np.where(pub.str.contains('Oxford'), 'Oxford',
        np.where(pub.eq('Newcastle upon Tyne'),
            'Newcastle-upon-Tyne', df['Place of Publication'])))

# %%
df.head()
# Out:
#            Place of Publication Date of Publication              Publisher  \
# Identifier
# 206                      London               1879        S. Tinsley & Co.
# 216                      London                1868           Virtue & Co.
# 218                      London                1869  Bradbury, Evans & Co.
# 472                      London                1851          James Darling
# 480                      London                1857   Wertheim & Macintosh
#
#                                                         Title    Author  \
# Identifier
# 206                                             Walter Forbes        AA
# 216                                             All For Greed   A. A A.
# 218                                          Love The Avenger   A. A A.
# 472         Welsh Sketches, Chiefly Ecclesiastical, To The...   E. S A.
# 480             The World In Which I Live, And My Place In It   E. S A.
#
# ...

# %% [markdown]
# ![logos](https://d28htnjz2elwuj.cloudfront.net/wp-content/uploads/2018/07/17153502/UniversityofMichigan_Feat_DieonRoger.jpg)

# %% [markdown]
# ## Limpando TUDO
# Agora já trataremos um outro conjunto de dados

# %%
# !more university_towns.txt
# Out:
# Alabama[edit]
# Auburn (Auburn University)[1]
# Florence (University of North Alabama)
# Jacksonville (Jacksonville State University)[2]
# Livingston (University of West Alabama)[2]
# Montevallo (University of Montevallo)[2]
# Troy (Troy University)[2]
# Tuscaloosa (University of Alabama, Stillman College, Shelton State)[3][4]
# Tuskegee (Tuskegee University)[5]
# Alaska[edit]
# Fairbanks (University of Alaska Fairbanks)[2]
# Arizona[edit]
# Flagstaff (Northern Arizona University)[6]
# Tempe (Arizona State University)
# Tucson (University of Arizona)
# Arkansas[edit]
# Arkadelphia (Henderson State University, Ouachita Baptist University)[2]
# Conway (Central Baptist College, Hendrix College, University of Central Arkansas
# )[2]
# Fayetteville (University of Arkansas)[7]
# Jonesboro (Arkansas State University)[8]
# Magnolia (Southern Arkansas University)[2]
# Monticello (University of Arkansas at Monticello)[2]
# m--Mais--(3%)

# %%
# Visualizamos acima que o dataset possui apenas uma coluna
# Entendemos que temos o EStado e suas respectivas universidades
# Vamos separar as mesmas para melhorar a visualização e se quisermos um tratamento dos dados
university_towns = []

with open('university_towns.txt', 'r') as file:
    items = file.readlines()
    states = list(filter(lambda x: '[edit]' in x, items))
    
    for index, state in enumerate(states):
        start = items.index(state) + 1
        if index == 49: #since 50 states
            end = len(items)
        else:
            end = items.index(states[index + 1])
            
        pairs = map(lambda x: [state, x], items[start:end])
        university_towns.extend(pairs)
        
towns_df = pd.DataFrame(university_towns, columns = ['State', 'RegionName'])
towns_df.head()
# Out:
#              State                                         RegionName
# 0  Alabama[edit]\n                    Auburn (Auburn University)[1]\n
# 1  Alabama[edit]\n           Florence (University of North Alabama)\n
# 2  Alabama[edit]\n  Jacksonville (Jacksonville State University)[2]\n
# 3  Alabama[edit]\n       Livingston (University of West Alabama)[2]\n
# 4  Alabama[edit]\n         Montevallo (University of Montevallo)[2]\n

# %%
def clean_up(item):
    if '(' in item:
        return item[:item.find('(') - 1]
    
    if '[' in item:
        return item[:item.find('[')]
    

    
towns_df =  towns_df.applymap(clean_up)
towns_df.head()
# Out:
#      State    RegionName
# 0  Alabama        Auburn
# 1  Alabama      Florence
# 2  Alabama  Jacksonville
# 3  Alabama    Livingston
# 4  Alabama    Montevallo

# %%
# Uma qtde boa  de dados
towns_df.count()
# Out:
# State         517
# RegionName    513
# dtype: int64

# %% [markdown]
# ![logos](https://nationaldailyng.com/wp-content/uploads/2018/03/summer-olympics.jpg)

# %% [markdown]
# ## Renomear colunas e ajustar linhas
# Agora já estamos no 3º dataset<p>
#     Ao importa-los já notamos algo de errado... perceba vc mesmo

# %%
olympics_df = pd.read_csv('olympics.csv')
olympics_df.head()
# Out:
#                    0         1     2     3     4      5         6     7     8  \
# 0                NaN  ? Summer  01 !  02 !  03 !  Total  ? Winter  01 !  02 !
# 1  Afghanistan (AFG)        13     0     0     2      2         0     0     0
# 2      Algeria (ALG)        12     5     2     8     15         3     0     0
# 3    Argentina (ARG)        23    18    24    28     70        18     0     0
# 4      Armenia (ARM)         5     1     2     9     12         6     0     0
#
#       9     10       11    12    13    14              15
# 0  03 !  Total  ? Games  01 !  02 !  03 !  Combined total
# 1     0      0       13     0     0     2               2
# 2     0      0       15     5     2     8              15
# 3     0      0       41    18    24    28              70
# 4     0      0       11     1     2     9              12

# %%
# Reparamos que a linha 0 contem o cabeçalho do conjunto de dados
# com uma sintaxe simples já arrumamos tudo
olympics_df = pd.read_csv('olympics.csv', skiprows = 1, header = 0)
olympics_df.head()
# Out:
#                 Unnamed: 0  ? Summer  01 !  02 !  03 !  Total  ? Winter  \
# 0        Afghanistan (AFG)        13     0     0     2      2         0
# 1            Algeria (ALG)        12     5     2     8     15         3
# 2          Argentina (ARG)        23    18    24    28     70        18
# 3            Armenia (ARM)         5     1     2     9     12         6
# 4  Australasia (ANZ) [ANZ]         2     3     4     5     12         0
#
#    01 !.1  02 !.1  03 !.1  Total.1  ? Games  01 !.2  02 !.2  03 !.2  \
# 0       0       0       0        0       13       0       0       2
# 1       0       0       0        0       15       5       2       8
# 2       0       0       0        0       41      18      24      28
# 3       0       0       0        0       11       1       2       9
# 4       0       0       0        0        2       3       4       5
#
#    Combined total
# 0               2
# 1              15
# 2              70
# 3              12
# 4              12

# %%
# Vamos agora renomear as mesmas, criando uma uniformidade pois em muitos momentos outras
# pessoas podem consultar o mesmo ....
new_names =  {'Unnamed: 0': 'Country',
              '? Summer': 'Summer Olympics',
              '01 !': 'Gold',
              '02 !': 'Silver',
              '03 !': 'Bronze',
              '? Winter': 'Winter Olympics',
              '01 !.1': 'Gold.1',
              '02 !.1': 'Silver.1',
              '03 !.1': 'Bronze.1',
              '? Games': '# Games', 
              '01 !.2': 'Gold.2',
              '02 !.2': 'Silver.2',
              '03 !.2': 'Bronze.2'}

olympics_df.rename(columns = new_names, inplace = True)

# %%
olympics_df.head()
# Out:
#                    Country  Summer Olympics  Gold  Silver  Bronze  Total  \
# 0        Afghanistan (AFG)               13     0       0       2      2
# 1            Algeria (ALG)               12     5       2       8     15
# 2          Argentina (ARG)               23    18      24      28     70
# 3            Armenia (ARM)                5     1       2       9     12
# 4  Australasia (ANZ) [ANZ]                2     3       4       5     12
#
#    Winter Olympics  Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# 0                0       0         0         0        0       13       0
# 1                3       0         0         0        0       15       5
# 2               18       0         0         0        0       41      18
# 3                6       0         0         0        0       11       1
# 4                0       0         0         0        0        2       3
#
#    Silver.2  Bronze.2  Combined total
# 0         0         2               2
# ...
