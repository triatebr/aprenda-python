# %% [markdown]
# <a href="https://colab.research.google.com/github/triatebr/aprenda-python/blob/master/Graph_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
#definindo variáveis que vamos usar nos exemplos
x = [1, 2, 3]
y = [10, 20, 30]
y2 = [15, 10, 40]
y3 = [20, 10, 35]
yBar = [3, 10, 7, 5, 3, 4.5, 6, 8.1]
z = [i * 1.5 for i in yBar]
xBar = range(len(yBar))
azul = "blue"
verde = "green"
preto = "black"

# %%
plt.plot(x, y)

# %%
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Título do gráfico')
plt.plot(x, y)

# %%
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Título do gráfico')
plt.plot(x, y)
plt.plot(x, y2)
plt.plot(x, y3)

# %%
plt.bar(xBar, yBar, color=azul)
# Out:
# <BarContainer object of 8 artists>

# %%
plt.bar(xBar, yBar, color=preto, align='center')
plt.plot(xBar, z, color=verde, marker='o', linestyle='--', linewidth=2)
